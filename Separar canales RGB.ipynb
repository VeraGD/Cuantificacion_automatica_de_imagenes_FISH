# %% [markdown]
# # Obtener imágenes de los distintos canales rgb de la imagen a color

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

from skimage import io
import imageio

# %% [markdown]
# ## Cargar imagen original

# %%
imagen = io.imread(fname="imageFISH.jpg")

# %%
io.imshow(imagen)
# Out:
# C:\Users\usuario\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# ## Funciones para crear las tres imágenes de los tres canales

# %%
def canal_r(image):
    f,c,a = image.shape
    canal = np.zeros((f,c))
    for i in range(0,f):
        for j in range(0,c):
            canal[i][j] = image[i][j][0]
    return canal

# %%
imagen_r = canal_r(imagen)

# %%
def canal_g(image):
    f,c,a = image.shape
    canal = np.zeros((f,c))
    for i in range(0,f):
        for j in range(0,c):
            canal[i][j] = image[i][j][1]
    return canal

# %%
imagen_g = canal_g(imagen)

# %%
def canal_b(image):
    f,c,a = image.shape
    canal = np.zeros((f,c))
    for i in range(0,f):
        for j in range(0,c):
            canal[i][j] = image[i][j][2]
    return canal

# %%
imagen_b = canal_b(imagen)

# %% [markdown]
# ## Comprobación de tamaños

# %%
imagen.shape
# Out:
# (1040, 1392, 3)

# %%
imagen_r.shape
# Out:
# (1040, 1392)

# %%
imagen_g.shape
# Out:
# (1040, 1392)

# %%
imagen_b.shape
# Out:
# (1040, 1392)

# %% [markdown]
# # Resultados en blanco y negro

# %% [markdown]
# ### Imagen original

# %%
plt.figure(figsize=(22,20))
plt.imshow(imagen)
plt.show()

# %% [markdown]
# ### Imagen canal r

# %%
plt.figure(figsize=(22,20))
plt.imshow(imagen_r, cmap = 'gray')
plt.show()

# %% [markdown]
# ### Imagen canal g

# %%
plt.figure(figsize=(22,20))
plt.imshow(imagen_g, cmap = 'gray')
plt.show()

# %% [markdown]
# ### Imagen canal b

# %%
plt.figure(figsize=(22,20))
plt.imshow(imagen_b, cmap = 'gray')
plt.show()

# %% [markdown]
# ## Guardar imágenes

# %%
imageio.imwrite('canal_r.jpeg', imagen_r)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.

# %%
imageio.imwrite('canal_g.jpeg', imagen_g)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 135.0]. Convert image to uint8 prior to saving to suppress this warning.

# %%
imageio.imwrite('canal_b.jpeg', imagen_b)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 231.0]. Convert image to uint8 prior to saving to suppress this warning.
